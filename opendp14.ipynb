# %% [raw]
# !pip install polars==1.32.0
# !pip install opendp[mbi]

# %%
import polars as pl
import opendp.prelude as dp
dp.enable_features("contrib")

# %%
data_path = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
metadata_path = "penguin_metadata.yaml"

# %%
lf = pl.scan_csv(
    data_path,
    schema_overrides={
        'species': pl.Enum(['Adelie']), 
        'island': pl.Enum(['Dream', 'Torgersen', 'Biscoe']), 
        'sex': pl.Enum(["MALE", "FEMALE"])}
).drop_nulls().collect()

# %%
lf.head(2)
# Out:
# shape: (2, 7)
# ┌─────────┬───────────┬────────────────┬───────────────┬───────────────────┬─────────────┬────────┐
# │ species ┆ island    ┆ bill_length_mm ┆ bill_depth_mm ┆ flipper_length_mm ┆ body_mass_g ┆ sex    │
# │ ---     ┆ ---       ┆ ---            ┆ ---           ┆ ---               ┆ ---         ┆ ---    │
# │ enum    ┆ enum      ┆ f64            ┆ f64           ┆ i64               ┆ i64         ┆ enum   │
# ╞═════════╪═══════════╪════════════════╪═══════════════╪═══════════════════╪═════════════╪════════╡
# │ Adelie  ┆ Torgersen ┆ 39.1           ┆ 18.7          ┆ 181               ┆ 3750        ┆ MALE   │
# │ Adelie  ┆ Torgersen ┆ 39.5           ┆ 17.4          ┆ 186               ┆ 3800        ┆ FEMALE │
# └─────────┴───────────┴────────────────┴───────────────┴───────────────────┴─────────────┴────────┘

# %% [markdown]
# ## Context API

# %%
context = dp.Context.compositor(
    data=lf.lazy(),
    privacy_unit=dp.unit_of(contributions=5),
    privacy_loss=dp.loss_of(rho=0.19, delta=1e-7),

)

# %%
table_aim = (
    context.query(rho=0.1, delta=0.0)
    # transformations/truncation may be applied here
    .select(
        "sex", "species", "island", 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm'
    ).contingency_table(
        keys={"sex": ["MALE", "FEMALE"],
              "species": ['Adelie'],
              "island": ['Dream', 'Torgersen', 'Biscoe']
             },
        cuts={"bill_length_mm": [30,42,54,65],'bill_depth_mm':[13,18,23], 'flipper_length_mm': [150,200,250]},
        algorithm=dp.mbi.AIM(),
    )
    .release()
)

# %%
table_aim.synthesize(rows=1000)
# Out:
# shape: (1_000, 6)
# ┌──────┬─────────┬───────────┬────────────────┬───────────────┬───────────────────┐
# │ sex  ┆ species ┆ island    ┆ bill_length_mm ┆ bill_depth_mm ┆ flipper_length_mm │
# │ ---  ┆ ---     ┆ ---       ┆ ---            ┆ ---           ┆ ---               │
# │ enum ┆ enum    ┆ enum      ┆ f64            ┆ f64           ┆ i64               │
# ╞══════╪═════════╪═══════════╪════════════════╪═══════════════╪═══════════════════╡
# │ MALE ┆ Adelie  ┆ Biscoe    ┆ 65.224869      ┆ 16.186863     ┆ 158               │
# │ MALE ┆ Adelie  ┆ Torgersen ┆ 65.104732      ┆ 14.468942     ┆ 187               │
# │ MALE ┆ Adelie  ┆ Dream     ┆ 33.261781      ┆ 14.656081     ┆ 173               │
# │ MALE ┆ null    ┆ null      ┆ 65.403681      ┆ 17.740775     ┆ 150               │
# │ null ┆ Adelie  ┆ null      ┆ 36.556358      ┆ 12.194968     ┆ 176               │
# │ …    ┆ …       ┆ …         ┆ …              ┆ …             ┆ …                 │
# │ MALE ┆ Adelie  ┆ Torgersen ┆ 65.38212       ┆ 14.870705     ┆ 195               │
# │ MALE ┆ Adelie  ┆ Torgersen ┆ 65.858644      ┆ 17.358386     ┆ 177               │
# │ MALE ┆ Adelie  ┆ null      ┆ 65.322856      ┆ 13.052434     ┆ 195               │
# │ MALE ┆ Adelie  ┆ Torgersen ┆ 65.077998      ┆ 17.244135     ┆ 150               │
# │ MALE ┆ Adelie  ┆ Dream     ┆ 65.196718      ┆ 12.902276     ┆ 188               │
# └──────┴─────────┴───────────┴────────────────┴───────────────┴───────────────────┘

# %% [markdown]
# ## Framework API

# %%
with open(metadata_path, "r") as f:
    metadata = yaml.safe_load(f)
dtypes, datetime_columns = get_df_types_from_metadata(metadata)
df_dummy = pd.read_csv(dummy_path, dtype=dtypes, parse_dates=datetime_columns)
df_dummy.head()

# %%
d_in = 1
input_metric = dp.symmetric_distance()
input_domain = dp.vector_domain(dp.atom_domain(T=float))

d_out = 1.0
privacy_measure = dp.max_divergence()

bounds = (0.0, 100.0)
imputed_value = 50.0

# %%
m_sc = dp.c.make_adaptive_composition(
    input_domain=input_domain,
    input_metric=input_metric,
    output_measure=privacy_measure,
    d_in=d_in,
    d_mids=[d_out / 3] * 3,
)

# %%
table_mst = (
    context.query(rho=0.1, delta=0.0)
    # transformations/truncation may be applied here
    .select(
        "sex", "species", "island", 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm'
    ).contingency_table(
        keys={"sex": ["MALE", "FEMALE"],
              "species": ['Adelie'],
              "island": ['Dream', 'Torgersen', 'Biscoe']
             },
        cuts={"bill_length_mm": [30, 42, 54, 65], 'bill_depth_mm':[13, 18, 23], 'flipper_length_mm': [150, 200, 250]},
        algorithm=dp.mbi.MST(),
    )
    .release()
)
# Out:
# ---------------------------------------------------------------------------
# OpenDPException                           Traceback (most recent call last)
# Cell In[9], line 14
#       1 table_mst = (
#       2     context.query(rho=0.1, delta=0.0)
#       3     # transformations/truncation may be applied here
#       4     .select(
#       5         "sex", "species", "island", 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm'
#       6     ).contingency_table(
#       7         keys={"sex": ["MALE", "FEMALE"],
#       8               "species": ['Adelie'],
#       9               "island": ['Dream', 'Torgersen', 'Biscoe']
#      10              },
#      11         cuts={"bill_length_mm": [30, 42, 54, 65], 'bill_depth_mm':[13, 18, 23], 'flipper_length_mm': [150, 200, 250]},
#      12         algorithm=dp.mbi.MST(),
#      13     )
# ---> 14     .release()
#      15 )
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/contingency_table.py:45, in ContingencyTableQuery.release(self, data, bounds, T)
#      38 def release(
#      39     self,
#      40     data=None,
#      41     bounds: Optional[tuple[float, float]] = None,
#      42     T: Optional[Union[Type[float], Type[int]]] = None,
#      43 ) -> ContingencyTable:
#      44     """Release the ContingencyTable."""
# ---> 45     return super().release(data, bounds, T)
#
# File /opt/python/lib/python3.13/site-packages/opendp/context.py:844, in Query.release(self, data, bounds, T)
#     841 measurement = self.resolve(bounds=bounds, T=T)
#     843 if self._context is not None:
# --> 844     answer = self._context(measurement)
#     845 elif data is not None:
#     846     answer = measurement(data)
#
# File /opt/python/lib/python3.13/site-packages/opendp/context.py:553, in Context.__call__(self, query)
#     551 def __call__(self, query: Measurement):
#     552     """Executes the given query on the context."""
# --> 553     answer = self.queryable(query)
#     555     # pop won't fail if queryable returned an answer
#     556     self.d_mids_consumed.append(
#     557         query.map(self.d_in) if self.d_mids is None else self.d_mids.pop(0)  # type: ignore[arg-type]
#     558     )
#
# File /opt/python/lib/python3.13/site-packages/opendp/mod.py:673, in OdometerQueryable.__call__(self, query)
#     671 def __call__(self, query):
#     672     from opendp.core import odometer_queryable_invoke
# --> 673     return odometer_queryable_invoke(self.value, query)
#
# File /opt/python/lib/python3.13/site-packages/opendp/core.py:977, in odometer_queryable_invoke(queryable, query)
#     974 # No type arguments to standardize.
#     975 # Convert arguments to c types.
#     976 c_queryable = py_to_c(queryable, c_type=AnyObjectPtr, type_name=None)
# --> 977 c_query = py_to_c(query, c_type=AnyObjectPtr, type_name=odometer_queryable_invoke_type(queryable))
#     979 # Call library function.
#     980 lib_function = lib.opendp_core__odometer_queryable_invoke
#
# File /opt/python/lib/python3.13/site-packages/opendp/core.py:1019, in odometer_queryable_invoke_type(this)
#    1016 lib_function.argtypes = [AnyObjectPtr]
#    1017 lib_function.restype = FfiResult
# -> 1019 output = c_to_py(unwrap(lib_function(c_this), ctypes.c_char_p))
#    1020 try:
#    1021     output.__opendp_dict__ = {
#    1022         '__function__': 'odometer_queryable_invoke_type',
#    1023         '__module__': 'core',
#    (...)   1026         },
#    1027     }
#
# File /opt/python/lib/python3.13/site-packages/opendp/_lib.py:337, in unwrap(result, type_)
#     335     if 'polars' in str(message).lower() and pl.__version__ != _EXPECTED_POLARS_VERSION:
#     336         message = f'Installed python polars version ({pl.__version__}) != expected version ({_EXPECTED_POLARS_VERSION}). {message}' # pragma: no cover
# --> 337 raise OpenDPException(variant, message, backtrace)
#
# OpenDPException:
#   FailedFunction("unknown ordering between (0.19999999999999998, 0.0) and (0.19, 1e-7)")

# %%
table_mst.synthesize(rows=1000)
