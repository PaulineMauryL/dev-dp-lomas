# %% [raw]
# !pip install polars==1.32.0
# !pip install opendp[mbi]

# %%
import polars as pl
import opendp.prelude as dp
import yaml
dp.enable_features("contrib")

# %%
data_path = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
metadata_path = "penguin_metadata.yaml"

# %%
with open(metadata_path, "r") as f:
    metadata = yaml.safe_load(f)

# %%
bl_lb = metadata["columns"]["bill_length_mm"]["lower"]
bl_ub = metadata["columns"]["bill_length_mm"]["upper"]

# %%
lf = pl.scan_csv(data_path).collect()
lf.head(2)
# Out:
# shape: (2, 7)
# ┌─────────┬───────────┬────────────────┬───────────────┬───────────────────┬─────────────┬────────┐
# │ species ┆ island    ┆ bill_length_mm ┆ bill_depth_mm ┆ flipper_length_mm ┆ body_mass_g ┆ sex    │
# │ ---     ┆ ---       ┆ ---            ┆ ---           ┆ ---               ┆ ---         ┆ ---    │
# │ str     ┆ str       ┆ f64            ┆ f64           ┆ i64               ┆ i64         ┆ str    │
# ╞═════════╪═══════════╪════════════════╪═══════════════╪═══════════════════╪═════════════╪════════╡
# │ Adelie  ┆ Torgersen ┆ 39.1           ┆ 18.7          ┆ 181               ┆ 3750        ┆ MALE   │
# │ Adelie  ┆ Torgersen ┆ 39.5           ┆ 17.4          ┆ 186               ┆ 3800        ┆ FEMALE │
# └─────────┴───────────┴────────────────┴───────────────┴───────────────────┴─────────────┴────────┘

# %%
lazy_lf = lf.lazy()

# %% [markdown]
# ## Context API

# %%
context = dp.Context.compositor(
    data=lazy_lf,
    privacy_unit=dp.unit_of(contributions=2),
    privacy_loss=dp.loss_of(epsilon=1.0),
    split_evenly_over=1,
    margins=[
        dp.polars.Margin(max_length=500),
    ],
)

# %% [markdown]
# ### Just a sum and len

# %%
mean_query = context.query().select(
    pl.col.bill_length_mm.cast(int).dp.sum(bounds=(30, 65)),
    dp.len()
)

# %%
mean_query.summarize()
# Out:
# shape: (2, 4)
# ┌────────────────┬──────────────┬─────────────────┬───────┐
# │ column         ┆ aggregate    ┆ distribution    ┆ scale │
# │ ---            ┆ ---          ┆ ---             ┆ ---   │
# │ str            ┆ str          ┆ str             ┆ f64   │
# ╞════════════════╪══════════════╪═════════════════╪═══════╡
# │ bill_length_mm ┆ Sum          ┆ Integer Laplace ┆ 260.0 │
# │ len            ┆ Frame Length ┆ Integer Laplace ┆ 4.0   │
# └────────────────┴──────────────┴─────────────────┴───────┘

# %%
mean_query.release().collect()
# Out:
# shape: (1, 2)
# ┌────────────────┬─────┐
# │ bill_length_mm ┆ len │
# │ ---            ┆ --- │
# │ i64            ┆ u32 │
# ╞════════════════╪═════╡
# │ 15095          ┆ 351 │
# └────────────────┴─────┘

# %% [markdown]
# ### A synthetic dataset

# %%
context = dp.Context.compositor(
    data=lazy_lf,
    privacy_unit=dp.unit_of(contributions=2),
    privacy_loss=dp.loss_of(rho=0.19, delta=1e-7),
    # split_evenly_over=1, error if has this parameter
    margins=[
        dp.polars.Margin(max_length=500),
    ],
)

# %%
table_aim = (
    context.query(rho=0.1, delta=0.0)
    .select(
        "sex", "species", "island", 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm'
    ).contingency_table(
        keys={
            "sex": ["MALE", "FEMALE"],
            "species": ['Adelie', 'Chinstrap', 'Gentoo'],
            "island": ['Dream', 'Torgersen', 'Biscoe']
             },
        cuts={
            "bill_length_mm": [30, 42, 54, 65],
            'bill_depth_mm': [13,18,23],
            'flipper_length_mm': [150,200,250]
        },
        algorithm=dp.mbi.AIM(),
    )
    .release()
)

# %%
table_aim.synthesize(rows=1000)
# Out:
# shape: (1_000, 6)
# ┌────────┬─────────┬───────────┬────────────────┬───────────────┬───────────────────┐
# │ sex    ┆ species ┆ island    ┆ bill_length_mm ┆ bill_depth_mm ┆ flipper_length_mm │
# │ ---    ┆ ---     ┆ ---       ┆ ---            ┆ ---           ┆ ---               │
# │ str    ┆ str     ┆ str       ┆ f64            ┆ f64           ┆ i64               │
# ╞════════╪═════════╪═══════════╪════════════════╪═══════════════╪═══════════════════╡
# │ MALE   ┆ Adelie  ┆ Biscoe    ┆ 42.938434      ┆ 21.436842     ┆ 177               │
# │ null   ┆ Adelie  ┆ Dream     ┆ 33.969006      ┆ 12.319888     ┆ 165               │
# │ FEMALE ┆ Adelie  ┆ Dream     ┆ 49.584048      ┆ 15.541649     ┆ 240               │
# │ MALE   ┆ Adelie  ┆ Biscoe    ┆ 50.929077      ┆ 16.395965     ┆ 175               │
# │ FEMALE ┆ Gentoo  ┆ Biscoe    ┆ 43.158024      ┆ 19.14188      ┆ 156               │
# │ …      ┆ …       ┆ …         ┆ …              ┆ …             ┆ …                 │
# │ MALE   ┆ Adelie  ┆ Torgersen ┆ 44.9507        ┆ 14.728648     ┆ 184               │
# │ FEMALE ┆ Gentoo  ┆ Dream     ┆ 40.659908      ┆ 18.910473     ┆ 209               │
# │ FEMALE ┆ Gentoo  ┆ Dream     ┆ 46.507862      ┆ 16.735932     ┆ 199               │
# │ FEMALE ┆ Gentoo  ┆ Biscoe    ┆ 50.456128      ┆ 16.750706     ┆ 232               │
# │ MALE   ┆ Adelie  ┆ Biscoe    ┆ 30.677635      ┆ 21.43531      ┆ 246               │
# └────────┴─────────┴───────────┴────────────────┴───────────────┴───────────────────┘

# %% [markdown]
# ## Framework API

# %%
from opendp_helper import get_raw_lf_domain, add_global_margin
from opendp import measures as ms

# %%
lf_domain = get_raw_lf_domain(metadata)

margin = dp.polars.Margin(max_length=metadata["rows"], invariant="keys")
lf_domain = dp.with_margin(lf_domain, margin)

# %% [markdown]
# ### Just a mean and len

# %%
plan = lazy_lf.select(
    pl.col("bill_length_mm").dp.mean(bounds=(bl_lb, bl_ub), scale=100), 
    dp.len(scale=1)
)
opendp_pipe = dp.m.make_private_lazyframe(
    lf_domain, dp.symmetric_distance(), ms.max_divergence(), plan
)
cost = opendp_pipe.map(d_in=int(metadata["max_ids"]))
print(f"Cost: {cost}")

release_data = opendp_pipe(lazy_lf)
release_data = release_data.collect()
release_data
# Out:
# Cost: 1.6600000000341588
# shape: (1, 2)
# ┌────────────────┬─────┐
# │ bill_length_mm ┆ len │
# │ ---            ┆ --- │
# │ f64            ┆ u32 │
# ╞════════════════╪═════╡
# │ 40.643018      ┆ 346 │
# └────────────────┴─────┘

# %%
lazy_lf.select(
    "sex", "species", "island", 
    'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm'
)
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>SELECT [col("sex"), col("species"), col("island"), col("bill_length_mm"), col("bill_depth_mm"), col("flipper_length_mm")]<p></p>  DF ["species", "island", "bill_length_mm", "bill_depth_mm", ...]; PROJECT */7 COLUMNS</div>

# %% [markdown]
# ### A synthetic dataset

# %%
from opendp.extras.mbi import make_contingency_table

# %%
lf_domain.columns
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
plan_aim = make_contingency_table(
    input_domain = lf_domain,
    input_metric = dp.symmetric_distance(),
    output_measure = ms.max_divergence(),
    d_in = 1,
    d_out = 1.0,
    keys={
        "sex": ["MALE", "FEMALE"],
        "species": ['Adelie', 'Chinstrap', 'Gentoo'],
        "island": ['Dream', 'Torgersen', 'Biscoe']
         },
    cuts={
        "bill_length_mm": [30, 42, 54, 65],
        "bill_depth_mm": [13, 18, 23],
        "flipper_length_mm": [150, 200, 250], 
        "body_mass_g": [2000, 4500, 7000]
    },
    algorithm=dp.mbi.AIM(),
)

# %%
opendp_pipe = dp.m.make_private_lazyframe(
    lf_domain, dp.symmetric_distance(), ms.max_divergence(), plan_aim
)
cost = opendp_pipe.map(d_in=int(metadata["max_ids"]))
print(f"Cost: {cost}")

release_data = opendp_pipe(lazy_lf)
release_data = release_data.collect()
release_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 opendp_pipe = dp.m.make_private_lazyframe(
#       2     lf_domain, dp.symmetric_distance(), ms.max_divergence(), plan_aim
#       3 )
#       4 cost = opendp_pipe.map(d_in=int(metadata["max_ids"]))
#       5 print(f"Cost: {cost}")
#
# File /opt/python/lib/python3.13/site-packages/opendp/measurements.py:1687, in make_private_lazyframe(input_domain, input_metric, output_measure, lazyframe, global_scale, threshold)
#    1685 c_input_metric = py_to_c(input_metric, c_type=Metric, type_name=None)
#    1686 c_output_measure = py_to_c(output_measure, c_type=Measure, type_name=None)
# -> 1687 c_lazyframe = py_to_c(lazyframe, c_type=AnyObjectPtr, type_name="LazyFrame")
#    1688 c_global_scale = py_to_c(global_scale, c_type=AnyObjectPtr, type_name=RuntimeType(origin='Option', args=["f64"]))
#    1689 c_threshold = py_to_c(threshold, c_type=AnyObjectPtr, type_name=RuntimeType(origin='Option', args=["u32"]))
#
# File /opt/python/lib/python3.13/site-packages/opendp/_convert.py:144, in py_to_c(value, c_type, type_name)
#     141         return value
#     143     from opendp._data import slice_as_object
# --> 144     return slice_as_object(value, type_name) # type: ignore[arg-type]
#     146 if c_type == FfiSlicePtr:
#     147     if type_name is None:
#
# File /opt/python/lib/python3.13/site-packages/opendp/_data.py:587, in slice_as_object(raw, T)
#     584 T = parse_or_infer(T, raw) # type: ignore
#     586 # Convert arguments to c types.
# --> 587 c_raw = py_to_c(raw, c_type=FfiSlicePtr, type_name=T)
#     588 c_T = py_to_c(T, c_type=ctypes.c_char_p, type_name=None)
#     590 # Call library function.
#
# File /opt/python/lib/python3.13/site-packages/opendp/_convert.py:149, in py_to_c(value, c_type, type_name)
#     147     if type_name is None:
#     148         raise ValueError("type_name must be known")  # pragma: no cover
# --> 149     return _py_to_slice(value, RuntimeType.parse(type_name))
#     151 if isinstance(value, RuntimeType):
#     152     value = str(value)
#
# File /opt/python/lib/python3.13/site-packages/opendp/_convert.py:371, in _py_to_slice(value, type_name)
#     368     return _series_to_slice(value)
#     370 if type_name in {"LazyFrame", "DslPlan"}:
# --> 371     return _lazyframe_to_slice(value)
#     373 if type_name == "DataFrame":
#     374     return _dataframe_to_slice(value)
#
# File /opt/python/lib/python3.13/site-packages/opendp/_convert.py:655, in _lazyframe_to_slice(val)
#     653 pl = import_optional_dependency('polars')
#     654 if not isinstance(val, pl.LazyFrame):
# --> 655     raise ValueError("expected Polars LazyFrame")
#     657 state = val.__getstate__()
#     658 raw = _wrap_in_slice(state, len(state))
#
# ValueError: expected Polars LazyFrame

# %%
plain_aim = make_contingency_table(
    keys={
        "sex": ["MALE", "FEMALE"],
        "species": ['Adelie', 'Chinstrap', 'Gentoo'],
        "island": ['Dream', 'Torgersen', 'Biscoe']
         },
    cuts={
        "bill_length_mm": [30, 42, 54, 65],
        "bill_depth_mm": [13, 18, 23],
        "flipper_length_mm": [150, 200, 250]
    },
    algorithm=dp.mbi.AIM(),
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 4
#       1 plain_aim = lazy_lf.with_columns(
#       2     "sex", "species", "island",
#       3     "bill_length_mm", "bill_depth_mm", "flipper_length_mm"
# ----> 4 ).contingency_table(
#       5     keys={
#       6         "sex": ["MALE", "FEMALE"],
#       7         "species": ['Adelie', 'Chinstrap', 'Gentoo'],
#       8         "island": ['Dream', 'Torgersen', 'Biscoe']
#       9          },
#      10     cuts={
#      11         "bill_length_mm": [30, 42, 54, 65],
#      12         'bill_depth_mm': [13, 18, 23],
#      13         'flipper_length_mm': [150, 200, 250]
#      14     },
#      15     algorithm=dp.mbi.AIM(),
#      16 )
#
# AttributeError: 'LazyFrame' object has no attribute 'contingency_table'
